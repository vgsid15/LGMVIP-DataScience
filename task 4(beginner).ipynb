# %% [markdown]
# Siddhaarthan V
#
# TASK - 4
# BEGINNER LEVEL
#
# IMAGE TO PENCIL SKETCH WITH PYTHON

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\siddhaarthan\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\siddhaarthan\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
#for various convertions

import cv2

# %%
import matplotlib.pyplot as plt

# %%
#reading image and converting it into normal

# %%
img = cv2.imread('dog.jpg')

img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img2)

# %% [markdown]
# converting it into gray image

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %% [markdown]
# #converting it into a negative image

# %%
inverted_image = 255 - gray_image
img2 = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
img2 = cv2.cvtColor(pencil_sketch, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
